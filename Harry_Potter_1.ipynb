# %%
import pandas as pd

# %%
data_dict = pd.read_csv('Harry_Potter_Movies/Data_Dictionary.csv')
data_dict
# Out:
#          Table           Field  \
# 0       Movies        Movie ID
# 1          NaN     Movie Title
# 2          NaN    Release Year
# 3          NaN         Runtime
# 4          NaN          Budget
# 5          NaN      Box Office
# 6     Chapters      Chapter ID
# 7          NaN    Chapter Name
# 8          NaN        Movie ID
# 9          NaN   Movie Chapter
# 10  Characters    Character ID
# 11         NaN  Character Name
# 12         NaN         Species
# 13         NaN          Gender
# 14         NaN           House
# 15         NaN        Patronus
# 16         NaN     Wand (Wood)
# 17         NaN     Wand (Core)
# 18      Places        Place ID
# 19         NaN      Place Name
# 20         NaN  Place Category
# 21      Spells        Spell ID
# 22         NaN     Incantation
# 23         NaN      Spell Name
# 24         NaN          Effect
# 25         NaN           Light
# 26    Dialogue     Dialogue ID
# 27         NaN      Chapter ID
# 28         NaN        Place ID
# 29         NaN    Character ID
# 30         NaN        Dialogue
#
#                                          Description
# 0                   Unique identifier for each movie
# 1                                    Full movie name
# 2            Year the movie was released in theaters
# 3                     Length of the movie in minutes
# 4                 Budget for the movie is US Dollars
# 5     Box office revenue for the movie in US Dollars
# 6                 Unique identifier for each chapter
# 7            Name of the chapter in the movie script
# 8             Foreign key to match with Movies table
# 9            Chapter number within each movie script
# 10              Unique identifier for each character
# 11                             Name of the character
# 12                          Species of the character
# 13                           Gender of the character
# 14  Hogwarts house (or name of other magical school)
# 15                         Patronus of the character
# 16             Type of wood for the character's wand
# 17                     Core for the character's wand
# 18                  Unique identifier for each place
# 19                                 Name of the place
# 20                                     Type of place
# 21                  Unique identifier for each spell
# 22                 Words needed to conjure the spell
# 23                                 Name of the spell
# 24                               What the spell does
# 25                             Light the spell casts
# 26       Unique identifier for each line of dialogue
# 27          Foreign key to match with Chapters table
# 28            Foreign key to match with Places table
# 29        Foreign key to match with Characters table
# 30            Line of dialogue from the movie script

# %% [markdown]
# ## Location Significance
# This section explores the importance of various places / settings where the scenes are filmed/stage
#
# **Data Needed**:
#
#     - Places
#     - Dialogue

# %%
places = pd.read_csv('Harry_Potter_Movies/Places.csv')
places_cat = list(set(places['Place Category']))

dialogue = pd.read_csv('Harry_Potter_Movies/Dialogue.csv', encoding='unicode_escape')
dialogue
# Out:
#       Dialogue ID  Chapter ID  Place ID  Character ID  \
# 0               1           1         8             4
# 1               2           1         8             7
# 2               3           1         8             4
# 3               4           1         8             7
# 4               5           1         8             4
# ...           ...         ...       ...           ...
# 7439         7440         234        71             1
# 7440         7441         234        71            84
# 7441         7442         234        71             1
# 7442         7443         234        71             1
# 7443         7444         234        71            84
#
#                                                Dialogue
# 0     I should have known that you would be here...P...
# 1     Good evening, Professor Dumbledore. Are the ru...
# 2      I'm afraid so, Professor. The good, and the bad.
# 3                                          And the boy?
# 4                               Hagrid is bringing him.
# ...                                                 ...
# 7439  Then Slytherin House will have gained a wonder...
# 7440                                            Really?
# 7441                                            Really.
# 7442                                             Ready?
# 7443                                             Ready.
#
# [7444 rows x 5 columns]

# %%
# Merge on Place ID
dialogue_place = pd.merge(places, dialogue, on="Place ID")
dialogue_place
# Out:
#       Place ID         Place Name           Place Category  Dialogue ID  \
# 0            1  Flourish & Blotts             Diagon Alley         1040
# 1            1  Flourish & Blotts             Diagon Alley         1041
# 2            1  Flourish & Blotts             Diagon Alley         1042
# 3            1  Flourish & Blotts             Diagon Alley         1043
# 4            1  Flourish & Blotts             Diagon Alley         1044
# ...        ...                ...                      ...          ...
# 7439        74            Unknown  Other Magical Locations         6930
# 7440        74            Unknown  Other Magical Locations         6931
# 7441        74            Unknown  Other Magical Locations         6932
# 7442        74            Unknown  Other Magical Locations         6933
# 7443        74            Unknown  Other Magical Locations         6934
#
#       Chapter ID  Character ID  \
# 0             39             5
# 1             39             1
# 2             39             5
# 3             39             3
# 4             39             5
# ...          ...           ...
# 7439         214             2
# 7440         215             1
# 7441         215             1
# 7442         215             2
# 7443         215             1
#
#                                                Dialogue
# 0     Yer a mess, Harry. Skulkin' 'round Knockturn A...
# 1     I was lost, I- hang on. What were you doing do...
# 2     Me? Oh, I was um I was lookin' for Flesh-Eatin...
# 3                                        Harry! Hagrid!
# 4                                      Hello, Hermione!
# ...                                                 ...
# 7439  'Fraid he's right. One problem: Snape's Headma...
# 7440  We'll go to Hogsmeade. To Honeydukes. Take the...
# 7441  There's something wrong with him. In the past,...
# 7442  Maybe it's because of the Horcruxes. Maybe he'...
# 7443  No. It's more like he's wounded. If anything, ...
#
# [7444 rows x 7 columns]

# %%
# Find the number of times a place name was featured, as well as the place category
placeNameFreq = dialogue_place.groupby(['Place Name'])['Dialogue'].count().reset_index()
placeNameFreq.rename({'Dialogue': 'Frequency'}, axis=1, inplace=True)
placeNameFreq.sort_values(['Frequency'], ascending=False)
# Out:
#                     Place Name  Frequency
# 19                  Great Hall        557
# 1               4 Privet Drive        347
# 22      Griffindor Common Room        343
# 37           Ministry of Magic        327
# 24                Hagrid's Hut        313
# ..                         ...        ...
# 39                 Ollivanders         10
# 31             Knockturn Alley          8
# 11              Detention Room          7
# 49          Restricted Section          7
# 54  Sixth-floor boys' bathroom          3
#
# [74 rows x 2 columns]

# %% [markdown]
# ## Character Relation
# This section explores the importance and relationship between characters
#
# Dataset Needed:
#
#     - relations.csv
#     - characters.csv

# %%
relations = pd.read_csv('Harry_Potter_Universe/relations.csv')
characters = pd.read_csv('Harry_Potter_Universe/characters.csv')

# %%
# Merge relations with character
character_dict = {}
for index, row in characters.iterrows():
    character_dict[row['id']] = row['name']
    
connections = relations.copy()
connections['source_name'] = connections['source'].apply(lambda x: character_dict[x])
connections['target_name'] = connections['target'].apply(lambda x: character_dict[x])
connections
# Out:
#      source  target type             source_name             target_name
# 0         0       1    -  Regulus Arcturus Black            Sirius Black
# 1         0      25    -  Regulus Arcturus Black     Bellatrix Lestrange
# 2         0      45    -  Regulus Arcturus Black          Lord Voldemort
# 3         1       0    -            Sirius Black  Regulus Arcturus Black
# 4         1      11    +            Sirius Black        Albus Dumbledore
# ..      ...     ...  ...                     ...                     ...
# 508      63      58    -                  Aragog             Ron Weasley
# 509      64      21    +                   Grawp        Hermione Granger
# 510      64      22    +                   Grawp           Rubeus Hagrid
# 511      64      39    +                   Grawp            Harry Potter
# 512      63      58    +                  Aragog             Ron Weasley
#
# [513 rows x 5 columns]

# %%
character_links = connections.groupby(['source_name'])['target_name'].apply(lambda x: ','.join(set(x))).reset_index()

# All characters per line
character_links['All'] = character_links['source_name'] + ',' + character_links['target_name']
character_links
# Out:
#                 source_name  \
# 0   Alastor "Mad-Eye" Moody
# 1     Alberforth Dumbledore
# 2          Albus Dumbledore
# 3          Alice Longbottom
# 4                    Aragog
# ..                      ...
# 60           Vernon Dursley
# 61              Viktor Krum
# 62           Vincent Crabbe
# 63       Vincent Crabbe Sr.
# 64     Xenophilius Lovegood
#
#                                           target_name  \
# 0   Molly Weasley,Bartemius "Barty" Crouch Jr.,Alb...
# 1   Albus Dumbledore,Dobby,Ron Weasley,Hermione Gr...
# 2   Lily Potter,Sirius Black,Ginny Weasley,Bill We...
# 3                 Frank Longbottom,Neville Longbottom
# 4   Rubeus Hagrid,Ron Weasley,Hermione Granger,Har...
# ..                                                ...
# 60  Albus Dumbledore,Dudley Dursley,Harry Potter,P...
# 61  Igor Karkaroff,Fleur Delacour,Cedric Diggory,H...
# 62  Dolores Janes Umbridge,Gregory Goyle,Draco Mal...
# 63  Bellatrix Lestrange,Lucius Malfoy,Severus Snap...
# 64                                      Luna Lovegood
#
#                                                   All
# 0   Alastor "Mad-Eye" Moody,Molly Weasley,Bartemiu...
# 1   Alberforth Dumbledore,Albus Dumbledore,Dobby,R...
# 2   Albus Dumbledore,Lily Potter,Sirius Black,Ginn...
# 3   Alice Longbottom,Frank Longbottom,Neville Long...
# 4   Aragog,Rubeus Hagrid,Ron Weasley,Hermione Gran...
# ..                                                ...
# 60  Vernon Dursley,Albus Dumbledore,Dudley Dursley...
# 61  Viktor Krum,Igor Karkaroff,Fleur Delacour,Cedr...
# 62  Vincent Crabbe,Dolores Janes Umbridge,Gregory ...
# 63  Vincent Crabbe Sr.,Bellatrix Lestrange,Lucius ...
# 64                 Xenophilius Lovegood,Luna Lovegood
#
# [65 rows x 3 columns]

# %%
# Write to textfile
links = list(character_links['All'])
with open('characters_link.txt', 'w') as f:
    for line in links:
        f.write(line)
        f.write('\n')

# %%
import pandas as pd
import seaborn as sns
import networkprocessing as np

# %%
# Read in the text file and process the network
np.make_network("characters_link.txt")
# Out:
# Processing characters_link.txt

# %%
# Examine the dataset
networkinfo = pd.read_excel('characters_link_analysis/networkInfo.xlsx')
nodeInfo = pd.read_excel('characters_link_analysis/nodeInfo.xlsx')

# %%
networkinfo
# Out:
#         network_id  nodes  edges  avg path length  avg degree  \
# 0  characters_link     65    962         1.566827        29.6
#
#    avg weighted degree  diameter  radius  density
# 0            90.923077         3       2   0.4625

# %%
nodeInfo
# Out:
#     Unnamed: 0                         label  degree  weighted_degree  \
# 0            0       Alastor "Mad-Eye" Moody      46              143
# 1            1                 Molly Weasley      43              168
# 2            2  Bartemius "Barty" Crouch Jr.      15               20
# 3            3              Albus Dumbledore      49              180
# 4            4                Lord Voldemort      57              322
# ..         ...                           ...     ...              ...
# 60          60                Moaning Myrtle       1                1
# 61          61                Nicolas Flamel       1                1
# 62          62                 Olympe Maxime      14               16
# 63          63        Regulus Arcturus Black      24               32
# 64          64          Xenophilius Lovegood       1                1
#
#     betweenness  normalized_betweenness  eccentricity  closeness  \
# 0     18.843783                0.009347             2   0.780488
# 1      8.069038                0.004002             2   0.752941
# 2      1.532490                0.000760             3   0.561404
# 3     99.274102                0.049243             2   0.810127
# 4    213.804573                0.106054             2   0.901408
# ..          ...                     ...           ...        ...
# 60     0.000000                0.000000             3   0.481203
# 61     0.000000                0.000000             3   0.450704
# 62     0.756818                0.000375             3   0.556522
# 63     3.219636                0.001597             3   0.609524
# 64     0.000000                0.000000             3   0.415584
#
#             network
# 0   characters_link
# 1   characters_link
# 2   characters_link
# 3   characters_link
# 4   characters_link
# ..              ...
# 60  characters_link
# 61  characters_link
# 62  characters_link
# 63  characters_link
# 64  characters_link
#
# [65 rows x 9 columns]
